# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

titanic=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\titanic.csv")

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 157          158         0       3                 Corn, Mr. Harry    male
# 264          265         0       3              Henry, Miss. Delia  female
# 116          117         0       3            Connors, Mr. Patrick    male
# 104          105         0       3  Gustafsson, Mr. Anders Vilhelm    male
# 252          253         0       1       Stead, Mr. William Thomas    male
#
#       Age  SibSp  Parch           Ticket    Fare Cabin Embarked
# 157  30.0      0      0  SOTON/OQ 392090   8.050   NaN        S
# 264   NaN      0      0           382649   7.750   NaN        Q
# 116  70.5      0      0           370369   7.750   NaN        Q
# 104  37.0      2      0          3101276   7.925   NaN        S
# 252  62.0      0      0           113514  26.550   C87        S

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
list(titanic.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
titanic.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titanic.Age.min(),titanic.Age.max(),titanic.Age.mean(),titanic.Age.median()
# Out:
# (np.float64(0.42),
#  np.float64(80.0),
#  np.float64(29.69911764705882),
#  np.float64(28.0))

# %%
titanic.Survived.mean()
# Out:
# np.float64(0.3838383838383838)

# %%
titanic.loc[889]
# Out:
# PassengerId                      890
# Survived                           1
# Pclass                             1
# Name           Behr, Mr. Karl Howell
# Sex                             male
# Age                             26.0
# SibSp                              0
# Parch                              0
# Ticket                        111369
# Fare                            30.0
# Cabin                           C148
# Embarked                           C
# Name: 889, dtype: object

# %%
titanic.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
child=titanic.Age<14
child.sum()
# Out:
# np.int64(71)

# %%
child.head(60)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43     True
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50     True
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58     True
# 59     True
# Name: Age, dtype: bool

# %%
child.mean()
# Out:
# np.float64(0.07968574635241302)

# %%
child=titanic[titanic.Age.isin(["A","B"])]
child.shape
# Out:
# (0, 12)

# %%
titanic[["Sex","Pclass","Survived"]].sample(4)
# Out:
#       Sex  Pclass  Survived
# 508  male       3         0
# 204  male       3         1
# 471  male       3         0
# 857  male       1         1

# %%
titanic.drop(["Name","Ticket","Age"],axis=1).head(60
                                                  )
# Out:
#     PassengerId  Survived  Pclass     Sex  SibSp  Parch      Fare  \
# 0             1         0       3    male      1      0    7.2500
# 1             2         1       1  female      1      0   71.2833
# 2             3         1       3  female      0      0    7.9250
# 3             4         1       1  female      1      0   53.1000
# 4             5         0       3    male      0      0    8.0500
# 5             6         0       3    male      0      0    8.4583
# 6             7         0       1    male      0      0   51.8625
# 7             8         0       3    male      3      1   21.0750
# 8             9         1       3  female      0      2   11.1333
# 9            10         1       2  female      1      0   30.0708
# 10           11         1       3  female      1      1   16.7000
# 11           12         1       1  female      0      0   26.5500
# 12           13         0       3    male      0      0    8.0500
# ...

# %%
titanic.drop(["Name","Ticket","Age"],axis=1).sample(4)
# Out:
#      PassengerId  Survived  Pclass     Sex  SibSp  Parch   Fare Cabin Embarked
# 181          182         0       2    male      0      0  15.05   NaN        C
# 615          616         1       2  female      1      2  65.00   NaN        S
# 185          186         0       1    male      0      0  50.00   A32        S
# 617          618         0       3  female      1      0  16.10   NaN        S

# %%
titanic.groupby("Sex")

# %%
titanic.groupby("Sex").Survived.mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
titanic.groupby(["Sex","Pclass"]).Survived.mean()
# Out:
# Sex     Pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: Survived, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

male_age = titanic[titanic.Sex == "male"].Age
female_age = titanic[titanic.Sex == "female"].Age
plt.hist([male_age, female_age], bins=30, stacked=True, label=["Male", "Female"])
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age Distribution by Sex")
plt.legend()
plt.show()

# %%
titanic.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
titanic.Cabin.str.contains("A")
# Out:
# 0        NaN
# 1      False
# 2        NaN
# 3      False
# 4        NaN
#        ...
# 886      NaN
# 887    False
# 888      NaN
# 889    False
# 890      NaN
# Name: Cabin, Length: 891, dtype: object

# %%
titanic.Cabin.str.contains(" ", na=False,regex=False).head(6)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: Cabin, dtype: bool

# %%
titanic.Cabin.head(6)
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# 5     NaN
# Name: Cabin, dtype: object

# %%
titanic.Cabin.str.contains(" ",na=False,regex=False).value_counts()
# Out:
# Cabin
# False    867
# True      24
# Name: count, dtype: int64

# %%
titanic.Cabin.str.match(r"\w\d+$", na=False).value_counts()
# Out:
# Cabin
# False    715
# True     176
# Name: count, dtype: int64

# %%
i = titanic.Cabin.str.match(r"\w\d+$", na=True)
titanic.Cabin[~i].sample(6)
# Out:
# 438        C23 C25 C27
# 97             D10 D12
# 292                  D
# 305            C22 C26
# 311    B57 B59 B63 B66
# 128              F E69
# Name: Cabin, dtype: object

# %%
(
    titanic
    .Cabin
    .str
    .replace(r"(\w).*", r"\1", regex = True)
    .dropna()  # many missing codes there
    .sample(6)
)
# Out:
# 572    E
# 297    C
# 671    B
# 781    B
# 291    B
# 689    B
# Name: Cabin, dtype: object

# %%
titanic["deck"] = titanic.Cabin.str.replace(r"(\w).*", r"\1", regex=True)   
titanic[["Cabin","deck"]].sample(6)
# Out:
#     Cabin deck
# 269   C99    C
# 799   NaN  NaN
# 204   NaN  NaN
# 406   NaN  NaN
# 787   NaN  NaN
# 39    NaN  NaN
